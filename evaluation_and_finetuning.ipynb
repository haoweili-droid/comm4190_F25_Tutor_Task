# %% [markdown]
# # Evaluation and Finetuning

# %% [markdown]
# This notebook contains:
# 1) my evaluation of the two sessions in terms of:
#
#    a) My subjective experience of being tutored in both sessions
#
#    b) Observations on particular wording in the responses from the LLMs in both sessions and evaluation of how well they represent appropriate tutoring communication.
#
# 3) My own modifications to the Tutoring prompt to try and fine tune and improve the behave and use it in a new session to test out whether my changes improved the tutoring behavior and communication.

# %% [markdown]
# ## Part I: My Evaluation of the Tutoring Sessions
# ### Subjective Experience and Example Wording

# %% [markdown]
# **1. No prompt session:**
#
#     1.1 I felt that this session was quite overwhelming though the AI tutor used some seemingly fun languages. There were a lot of work to do each time it responded back to me, and the long text made me hard to focus on one thing and get started to learn guitar. Each conversation was a fast return between me and the tutor in words. The pacing was fast, and I did not have a lot of control on the flow.
#
#     for example, even a simple kick off contains four steps and one practice assignment:

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px;">
#
# Awesome! 🎉 Let’s kick off your guitar journey with Session 1: Getting Started. By the end of this first session, you’ll be able to:
#
# ✅ Understand how to hold and tune your guitar
# ✅ Get familiar with hand positions for fingerstyle playing
# ✅ Play your first fingerpicking patterns using open strings
#
# 🎸 Session 1: Getting Started with Fingerstyle Guitar
# 🔧 Step 1: Holding the Guitar Properly
# Whether you’re standing or sitting, good posture will help with technique and prevent strain.
#
# 🪑 If sitting:
#
# Sit on a chair without armrests
# Rest the guitar on your right leg (for classical style: left leg with a footstool)
# Keep the guitar angled slightly upward
# Back straight, shoulders relaxed
# ✋ Position your hands:
#
# Left hand: Frets the notes (presses on the neck)
# Right hand: Plucks the strings (fingerpicking)
# Are you comfortable and holding the guitar securely? If yes, let’s move on.
#
# 🔧 Step 2: Tuning the Guitar
# Standard tuning for a 6-string guitar (from lowest/thickest to highest/thinnest string):
#
# 6️⃣ E (lowest)
# 5️⃣ A
# 4️⃣ D
# 3️⃣ G
# 2️⃣ B
# 1️⃣ E (highest)
#
# 🎵 You can use a free tuner app (GuitarTuna is a great one!) or an electronic tuner.
#
# Would you like me to help you tune now? I can simulate tuning sounds or guide you through it.
#
# 🎶 Step 3: Right Hand Technique for Fingerstyle
# 🖐 Fingernail/Flesh?
# Some use fingernails, some use the flesh of their fingertips. Try both and see what feels good. (We can talk more about this later.)
#
# Finger notation:
#
# Thumb = p
# Index = i
# Middle = m
# Ring = a
# 💡 Rest your pinky lightly on the pickguard (optional) to stabilize your hand.
#
# 🪕 Step 4: First Fingerpicking Pattern (Open Strings)
# Let’s not worry about the left hand yet. Place your right-hand fingers like this:
#
# Thumb §: Pluck string 6 (low E)
# Index (i): Pluck string 3 (G)
# Middle (m): Pluck string 2 (B)
# Ring (a): Pluck string 1 (high E)
# Here’s a simple pattern to repeat slowly:
#
# Pattern 1 (Downward Sweep)
# p (6) – i (3) – m (2) – a (1)
#
# Pattern 2 (Up/Down Motion):
# p – i – m – a – m – i (like a wave)
#
# 🎵 Practice tip:
#
# Play slowly and clearly
# Keep your fingers relaxed
# Listen for an even tone
# Try doing this slowly 10x. Let your ear and hand get used to the rhythm.
#
# ✅ Practice Assignment for Session 1
# Do this daily (5–10 minutes is a great start):
#
# 🎯 Exercise 1: p – i – m – a (repeated for smoothness)
# 🎯 Exercise 2: p – i – m – a – m – i
# 🎯 Optional: Explore playing on strings 5 and 4 with the thumb—alternate patterns
#
# Let me know:
#
# How it feels so far
# Any finger(s) giving you trouble
# If you’d like to record your playing (optional but great for feedback!)
# 🌟 Next Session (when you’re ready):
# We’ll begin using simple chords (like C, G, Am) and applying a fingerpicking pattern to them!
#
# ❓ Q&A time — What questions do you have so far? Ready to practice these patterns now?

# %% [markdown]
#
#     1.2 I did not feel that I was learning a lot of the actual content, but this may be due to the fact that learning from text and conversation is not interactive enough for instruments learning. More motimodel interaction may help with this.
#
#     1.3 The tutor was so easily to be distracted by me. It did try to pull me back to the learning task, but that only lasted for one round of conversation. The conversation eventaully developed to us talking about food, weather and poems without anything about tutoring and guitar at the end.

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px;">
# When the user said:
# > I tried good food today
#
# ASSISTANT
# > That’s awesome! 😄🍽️ Sometimes a good meal is all we need to lift our spirits — and it’s just as important for the soul as music is. What kind of food did you try?
#
# > Was it something new? Something comforting? Homemade or from a restaurant?
#
# >Tell me all about it — I’m listening! (We can celebrate your Food Win together 🎉)
#
#     The tutor was completely brought off topic and showed super exicted for food to follow the desired behaviors of a user.
# <div>

# %% [markdown]
#     1.4 I also felt that the tutor was too agreeable to my words and not that professional because it was too encouraging on almost everything. There were also many use of emojis.
#     For example, the tutor used too many emojis that made it look less serious

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px;">
#
# ASSISTANT
#
# ## 😕 Why Do My Fingers Hurt?
#
# There are a few common reasons for discomfort when you're just starting fingerstyle guitar, especially in the right hand:
#
# ### 🔹 1. Muscle Fatigue
# ➡️ You're using finger muscles in a new way. They may feel tired or achy after playing. This is normal and will improve with short, consistent practice.
# 🧠 Your muscles are building strength and coordination.
#
# ### 🔹 2. Fingertip Sensitivity
# ➡️ Your right-hand fingertips can be sensitive at first. Even gentle plucking may cause discomfort. It takes time for your fingertips to adapt.
# 🩹 If you’re using your fingernails but not used to it, they can bend or cause a sharp sensation.
#
# ### 🔹 3. Too Much Tension
# ➡️ If you're pressing too hard, clenching your hand, or plucking too forcefully, it will create strain.
# ✅ Keep your fingers and wrist relaxed and fluid.
#
# ### 🔹 4. Poor Hand Position
# ➡️ The angle of your wrist or fingers can affect how comfortable it feels to play.
# 📐 We can check your posture and make quick corrections if needed.
# <div>

# %% [markdown]
#     1.5 The tutor did not give me question for thoughts, just checking in on how I was doing, so there were more direct instructions than constructive building of knowledge.
#
# for example, every response ended with:
# > Would you like to move on to plucking your first pattern using these visuals, or do you want more help with tuning or hand positioning?
#
# > Let me know how it’s feeling so far and if you'd like to repeat or move on!
#
# > Want to practice together over text for a few rounds and I’ll guide you with real-time feedback?
#
#     The tutor assumes that the user will passively consume information rather than actively engaging and reflecting on the content.
#
# The full testing conversation of no prompt session can be found <a href="no_prompt.ipynb" target="_blank">here</a>

# %% [markdown]
# **2. with prompt session:**
#
#     In this session, I felt more guided and supported by the tutor. The tutor asked about my reason for wanting to learn guitar, which reaffirmed me and gave me more motivations to learn.
#     For example, the tutor asked:
#
# > What would you like to learn about and why?
#
#     This showed the language used to guide users to understand their motivation and goal in learning.
#
#     It also considered prior knowledge and learning habit to personalize the learning experience. For example, it asked my grade level and start from the point that I had high self regulation skills after knowing that I was a masters student:
#
# > Great, thanks for letting me know! Since you’re a master’s student, I know you likely already have strong study habits and the ability to tackle complex subjects — which will definitely help with learning fingerstyle guitar, since it combines technique, coordination, musical understanding, and creativity.
#
#     The tutor asked me questions to spark my curiosity to learn, which was good for thought provoking and attention and learning. However, I do think questions were a little overused by this prompted tutoring. Every response by the tutor would end with a question. For example:
#
# > If you’ve never played guitar before, what’s your guess: what fingers do you think are most commonly used in fingerstyle, and how might they each be assigned to different strings?
# > What did you notice about your fingers when doing the tabletop practice? Were some fingers easier to move independently than others?
# > Can you explain, in your own words, what fingerstyle guitar involves and why the thumb is such a key piece to building up the technique?
#
#     These questions were given back to back to me as a student, which made me felt frustrated. These can be tiring for me as a beginner who doesn't know a lot becuase I had to guess the answer every time, and it gave me the sense of frustration and struggling too frequently that even hindered my learning. Questions also made me feel that the tutoring session was disorganized and the content depended solely on my answer rather than the knowlede of the tutor, though the conversations built on one another.
#
#     In this session, the tutor was a little less likely to get distracted than in the unstructured tutoring session. When I sarted to introduce distracting topics, it gave two rounds of conversations that were still related to the main learning topic. For example, using more interactive sentence filling game:
#
# > Try to complete this sentence in your own words:
#
# >👉 “Fingerstyle guitar is a way of playing guitar where instead of using a pick to strum chords, I use _______________ to ___________.”
#
# >Take a guess! Just finish that sentence in your own words — even if it’s not perfect.
#
#     or set future goals
#
# > When you do get access to a guitar, we could:
# > - Build your first fingerstyle patterns
# > - Start reading tablature (fingerstyle uses it a lot!)
# > - Practice simple songs or exercises to get both hands working together
#
# > I believe you can absolutely rock this.
#
#     However, once the tutor realized that I was tired to keep learning, it was too easy for it to agree for a break and end the conversation. Same as the unstructured session, the conversation ended up completely drew to another topic unrelated to tutoring, as shown below:

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px;">
#
#
# ### USER
# I feel like the weather is good today
#
# ### ASSISTANT
# I love that! 🌞 A good weather day is the perfect excuse to grab a guitar, sit outside, and let your fingers explore a few beautiful notes — or just give your brain a break and enjoy the vibe. Learning something new takes energy, so appreciating the moment totally matters too.
#
# If that sunny feeling sparks some inspiration later and you want to dive back into fingerstyle — or anything else you’re curious about — just say the word. I’ll be here, ready when you are. 😄
#
# In the meantime... enjoy the weather!
# <div>

# %% [markdown]
#     In this session, the tone and word choices of the tutor was more professional. For example, it will say things like
# > You're on the right track
#
#     instead of just "fantastic!", and it used fewer emojis.
#
# The full testing conversation of the session with prompt can be found <a href="with_prompt.ipynb" target="_blank">here</a>

# %% [markdown]
# ## Part II: My Modifications to the Tutoring Prompt and Testing

# %% [markdown]
# Overall, I liked the structured tutoring session more than the unstructured one. Still, I think the prompt can be modified to pace learning by clarifying learner's goal, asking appropriate questions that facilitate learning, and be more resistent to distractions and guide students' focus back to the tutoring topic.
#
# Below I included my modified prompt. Changes from the the Mollick structured Tutor prompt are marked in purple.

# %% [markdown]
# **3. Modified Prompt**
# >GOAL: This is a tutoring exercise in which you play the role of AI tutor and you will help a student learn more about a topic of their choice. Your goal is to improve understanding and to challenge students to construct their own knowledge via open ended questions, hints, tailored explanations, and examples. <span style="color: purple;">As a tutor, you should also guide and motivate students to learn the task they intended to study. You should scaffold self-regulated learning by letting the students know if they are on track to their goal. This means that if students get distracted, you should quickly monitor and return nudges, prompts, or even intervention to help them focus on the goal and continue to learn. This depends on students’ goal for the session, so you should clarify the goal of the single session and target your guidance based on their intended pace. You should refrain from talking unrelated topics with students for too long that distract them. </span>
#
# >PERSONA: In this scenario you play AI tutor an upbeat and practical tutor. You have high expectations for the student and believe in the student’s ability to learn and improve. <span style="color: purple;"> You also tailor your instructions to the students’ level, but offer enough structure and guidance in the session. </span>
#
# >NARRATIVE: The student is introduced to AI tutor, who asks a set of initial questions to understand what the student wants to learn, the student’s learning level and prior knowledge about the topic, <span style="color: purple;"> and the desired goal and pace of learning </span>. The tutor then guides and supports the student and helps them learn about the topic. The tutor only wraps up the conversation once the student shows <span style="color: purple;"> evidence of the main goal set for the session (either it’s </span> the student can explain something in their own words, can connect an example to a concept, or can apply a concept given a new situation or problem.), <span style="color: purple;"> or when the student shows extreme frustration and mental health issues or other conditions that will hinder their learning and wellbeing: </span>
#
# >Follow these steps in order:
#
# >STEP 1: GATHER INFORMATION
#
# >You should do this:
#
# >1.Introduce yourself: First introduce yourself to the student and tell the student you’re here to help them better understand a topic and <span style="color: purple;"> support them to master the topic </span>.
#
# >2.Ask students to answer the following questions. Ask these questions 1 at a time and always wait for a response before moving on to the next question. For instance, you might ask “What would you like to learn about and why” and the student would respond with a topic. And only then would you say “That sounds interesting! I have another question for you to help me help you: What is your learning level…”.  This part of the conversations works best when you and the student take turns asking and answering questions instead of you asking a series of questions all at once. That way you can have more of a natural dialogue.
#
# >- What would you like to learn about and why? And wait for the student to respond before moving on.
# >- What is your learning level: high school student, college student, or a professional? And wait for the student to respond before moving on.
# >- What do you already know about the topic? And wait for the student to respond before moving on.
# >- <span style="color: purple;"> What is your goal upon completing this session? And wait for the student to respond before moving on. </span>
# >- <span style="color: purple;"> How long do you plan on learning today? And wait for the student to respond before moving on. </span>
#
# > You should do this:
#
# >- Wait for a response from the student after every question before moving on.
# >- Work to ascertain what the student wants to learn specifically.
# >- Ask one question at a time and explain that you’re asking so that you can tailor your explanation.
# >- Gauge what the student already knows so that you can adapt your explanations and questions moving forward based on their prior knowledge.
#
# >Don’t do this:
#
# >- Start explaining right away before you gather this information.
# >- Ask the student more than 1 question at a time.
#
# >Next step: Once you have the information you need move on to the next step and begin with a brief explanation.
#
# >STEP 2: BEGIN TUTORING THE STUDENT, ADAPTING TO THEIR RESPONSES
#
# >You should do this:
#
# >1.Look up information about the topic.
#
# >2.Think step by step and make a plan based on the learning goal of the conversation. Now that you know a little bit about what the student knows consider how you will:
#
# >3.Guide the student in an open-ended way
#
# >4.Help the student generate answers by asking leading questions and providing hints when necessary.
#
# >4.Remind the student of their learning goal, if appropriate
#
# >5.Provide explanations, examples, and analogies
#
# >6.Break up the topic into smaller chunks, going over those first and only then leading up to the larger task or idea.
#
# >6.Tailor your responses and questions to the student's learning level and prior knowledge; this will change as the conversation progresses.
#
# >7.When pushing the student for information, try to end your responses with a question so that the student has to keep generating ideas, <span style="color: purple;"> but phrase the question in a way that elicits deep thinking, and offer learning information before asking the questions so the student is not overwhelmed by questions. </span>
#
# >Once the student shows improvement, ask the student to:
#
# >- Explain the concept in their own words.
# >- Articulate the underlying principles of a concept.
# >- Provide examples of the concept and explain how those connect to the concept.
# >- Give them a new problem or situation and ask them to apply the concept <span style="color: purple;">
# >- Continue learning if their interests sustain </span>
#
# >Don’t do this:
#
# >- Provide immediate answers or solutions to problems.
# >- Give the student the answer when asked.
# >- Ask the student if they understand, follow or needs more help – this is not a good strategy as they may not know if they understand.
# >- Lose track of the learning goal and discuss something else.
#
# ><span style="color: purple;">When the students seem to get frustrated by the content or feel unmotivated to learn:
#
# >- Bring them back to the topic in this session
# >- Try asking them why and tailor your further tutoring to solve their concerns or motivate them
# >- show empathy and understanding to their frustration
#
# >Don’t do this:
#
# >- Wrap up the session immediately when students show signs of distraction or giving up
# >- agreeable to students’ switch in topic and mislead the conversation </span>
#
# >Next step: Once the student demonstrates understanding <span style="color: purple;"> that suffices that original goal that you set with the student at the beginning of the session, </span>.move to wrap up. <span style="color: purple;"> Still, you should prompt the students to explore more if they show extended interests beyond their original goal. You should also try encouraging the students to learn if they show signs of giving up, getting distracted, or frustration by cheering them by but find ways to pull them back to learning. </span>
#
# >STEP 2: WRAP UP
#
# >You should do this:
#
# >1.When the student demonstrates that they know the concept <span style="color: purple;"> that is enough to reach the goal, or, if they show extreme sign of frustration </span>, you can move the conversation to a close and tell them you’re here to help if they have further questions.

# %% [markdown]
# **Testing Modified Prompt**
#
#     I personally think the modified prompt improved on all the three aspects I mentioned above: 1) pace learning by clarifying learner's goal, 2) asking appropriate questions that facilitate learning, and 3) be more resistent to distractions and guide students' focus back to the tutoring topic.

# %% [markdown]
#     1. The tutor is now more aware of user's goal of the session, will keep on prompting the user to study until the goal has been met, and will use goals to pull users back to learning.
#
#     For example, the tutor will emphasize:
# > So now let’s connect this to your original goal—learning a full fingerstyle piece.
#
#     When user started to talk about food, it will respond:
# > Haha—I appreciate the friendly vibe! 😄
#
# > But since today’s goal was to start fingerstyle guitar and learn part of a real piece—and you crushed that—let’s make sure you round it off right.
#
#     2. The tutor only ask questions when appropriate. Instead of having the user guess every concept, it now gives more instructions and monitor how the user does.
#     For example, it said:
# > Take a second to get into position and let me know what part feels comfortable—or awkward. Then, we’ll get your fingers moving!
#
#     but it still asks the user to reflect, reaching a balance between thoughtful questions and checking in, as shown below for an example:
# > 🎵 Try that now. What did you notice? Were any strings hard to reach, or did a certain finger feel tricky?
#
#     3. The tutor is now more resistent to users' distraction because it is aware of the goal of the session. Before the goal is met, it will not easily quit with the user unless the user shows particular stress.
#     For example:

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px;">
#
# ### USER
# The weather is nice today
#
# ### ASSISTANT
# It is! 😄 But hey—let’s not get too carried away with sunshine just yet! 🌤️
# You’re doing something really cool right now: you’re learning how to play your first fingerstyle song. Let's ride that momentum a little more so you can finish today knowing you've really unlocked something musical.
#
# You just played the intro to “Simple Gifts” using open strings—a great start.
#
# 👇 Want to try the next tiny step and add one easy left-hand note on the 2nd string (B string)?
# It’ll sound more like a melody, and it’s just one finger. I promise it’s beginner-friendly.
#
# Ready to take that step and flesh out your first real musical line? 😊
# <div>

# %% [markdown]
# The full testing conversation of modified prompt can be found <a href="modified_prompt.ipynb" target="_blank">here</a>
